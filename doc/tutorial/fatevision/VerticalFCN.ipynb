# %% [markdown]
# # Vertical Federated Image Segmentation
#
# A Vertical Image Segmentation implementation to detect roads in the CamVid Dataset.
#
# CamVid is available here: https://www.kaggle.com/datasets/carlolepelaars/camvid

# %% [markdown]
# ## Dataset
#
# In version FATE-1.10, FATE introduces a new base class for datasets called Dataset, which is based on PyTorch's Dataset class. This class allows users to create custom datasets according to their specific needs. The usage is similar to that of PyTorch's Dataset class, with the added requirement of implementing two additional interfaces when using FATE-NN for data reading and training: load() and get_sample_ids().
#
# To create a custom dataset in Hetero-NN, users need to:
#
# - Develop a new dataset class that inherits from the Dataset class
# - Implement the \_\_len\_\_() and \_\_getitem\_\_() methods, which are consistent with PyTorch's Dataset usage. The \_\_len\_\_() method should return the length of the dataset, while the \_\_getitem\_\_() method should return the corresponding data at the specified index. **However, please notice that different \_\_getitem\_\_() methods may have different behaviors between different parties. In the guest party(party with labels), _\_getitem\_\_() method return features and labels, while in the host parties(parties without label), _\_getitem\_\_() method return features only.**
# - Implement the load(), get_sample_ids(), get_classes() methods
#
# For those unfamiliar with PyTorch's Dataset class, more information can be found in the PyTorch documentation: [Pytorch Dataset Documentation](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)
#
# ## Customize Bottom/Top Model
#
# Name the model code bottom_net.py,  you can put it directly under federatedml/nn/model_zoo or use the shortcut interface of jupyter notebook: save_to_fate, to save it directly to federatedml/nn/model_zoo. This is the bottom model structure we define for feature extraction.

# %%
from pipeline.component.nn import save_to_fate

# %%
# %%save_to_fate model fcn_top.py
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from federatedml.util import LOGGER
#
# class FCN_Top(nn.Module):
#
#     def __init__(self, n_class=1):
#         super().__init__()
#         self.n_class = n_class
#
#         self.relu    = nn.ReLU(inplace=True)
#         self.deconv1 = nn.ConvTranspose2d(512, 512, kernel_size=3, stride=2, padding=1, dilation=1, output_padding=1)
#         self.bn1     = nn.BatchNorm2d(512)
#         self.deconv2 = nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, dilation=1, output_padding=1)
#         self.bn2     = nn.BatchNorm2d(256)
#         self.deconv3 = nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, dilation=1, output_padding=1)
#         self.bn3     = nn.BatchNorm2d(128)
#         self.deconv4 = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, dilation=1, output_padding=1)
#         self.bn4     = nn.BatchNorm2d(64)
#         self.deconv5 = nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, dilation=1, output_padding=1)
#         self.bn5     = nn.BatchNorm2d(32)
#         self.classifier = nn.Conv2d(32, n_class, kernel_size=1)
#
#         self.linear5 = nn.Linear(25,512*4*4)
#         self.linear4 = nn.Linear(50,512*8*8)
#         self.linear3 = nn.Linear(75,256*16*16)
#         self.linear2 = nn.Linear(150,128*32*32)
#         self.linear1 = nn.Linear(200,64*64*64)
#
#         self.unflatten5 = nn.Unflatten(dim=1, unflattened_size=(512,4,4))
#         self.unflatten4 = nn.Unflatten(dim=1, unflattened_size=(512,8,8))
#         self.unflatten3 = nn.Unflatten(dim=1, unflattened_size=(256,16,16))
#         self.unflatten2 = nn.Unflatten(dim=1, unflattened_size=(128,32,32))
#         self.unflatten1 = nn.Unflatten(dim=1, unflattened_size=(64,64,64))
#
#     def forward(self, x):
#
#         x = x.permute(1,0)
#
#         x5 = x[0:25]
#         x4 = x[25:75]
#         x3 = x[75:150]
#         x2 = x[150:300]
#         x1 = x[300:500]
#
#         x5 = x5.permute(1,0)
#         x4 = x4.permute(1,0)
#         x3 = x3.permute(1,0)
#         x2 = x2.permute(1,0)
#         x1 = x1.permute(1,0)
#
#         LOGGER.info(x5.shape)
#
#         x5 = self.linear5(x5)
#         x5 = self.unflatten5(x5)
#         #x5 = x5.unsqueeze(1)
#         x4 = self.linear4(x4)
#         x4 = self.unflatten4(x4)
#         #x4 = x4.unsqueeze(1)
#         x3 = self.linear3(x3)
#         x3 = self.unflatten3(x3)
#         #x3 = x3.unsqueeze(1)
#         x2 = self.linear2(x2)
#         x2 = self.unflatten2(x2)
#         #x2 = x2.unsqueeze(1)
#         x1 = self.linear1(x1)
#         x1 = self.unflatten1(x1)
#         #x1 = x1.unsqueeze(1)
#
#
#         score = self.bn1(self.relu(self.deconv1(x5)))     # size=(N, 512, x.H/16, x.W/16)
#
#         score = score + x4                                # element-wise add, size=(N, 512, x.H/16, x.W/16)
#         score = self.bn2(self.relu(self.deconv2(score)))  # size=(N, 256, x.H/8, x.W/8)
#         score = score + x3                                # element-wise add, size=(N, 256, x.H/8, x.W/8)
#         score = self.bn3(self.relu(self.deconv3(score)))  # size=(N, 128, x.H/4, x.W/4)
#         score = score + x2                                # element-wise add, size=(N, 128, x.H/4, x.W/4)
#         score = self.bn4(self.relu(self.deconv4(score)))  # size=(N, 64, x.H/2, x.W/2)
#         score = score + x1                                # element-wise add, size=(N, 64, x.H/2, x.W/2)
#         score = self.bn5(self.relu(self.deconv5(score)))  # size=(N, 32, x.H, x.W)
#         score = self.classifier(score)                    # size=(N, n_class, x.H/1, x.W/1)
#
#         score = score.squeeze(1)
#
#         return score  # size=(N, n_class, x.H/1, x.W/1)

# %%
# %%save_to_fate model dummy.py
# import torch as t
# from torch import nn
# from torch.nn import Module
#
# class DummyNet(nn.Module):
#
#     def __init__(self):
#         super(DummyNet, self).__init__()
#         self.fc = t.nn.Linear(1,1)
#
#     def forward(self, x):
#         #x = x.reshape([-1, 1])
#         x = self.fc(x)
#         return x

# %% [markdown]
# And here is the bottom model

# %%
# %%save_to_fate model fcn_bottom.py
# import torch as t
# from torch import nn
# from torch.nn import Module
# import torch.optim as optim
# from torchvision import models
# from torchvision.models.vgg import VGG
# from federatedml.util import LOGGER
#
# ranges = {
#     'vgg11': ((0, 3), (3, 6),  (6, 11),  (11, 16), (16, 21)),
#     'vgg13': ((0, 5), (5, 10), (10, 15), (15, 20), (20, 25)),
#     'vgg16': ((0, 5), (5, 10), (10, 17), (17, 24), (24, 31)),
#     'vgg19': ((0, 5), (5, 10), (10, 19), (19, 28), (28, 37))
# }
#
# # cropped version from https://github.com/pytorch/vision/blob/master/torchvision/models/vgg.py
# cfg = {
#     'vgg11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
#     'vgg13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
#     'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
#     'vgg19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
# }
#
# def make_layers(cfg, batch_norm=False):
#     layers = []
#     in_channels = 3
#     for v in cfg:
#         if v == 'M':
#             layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
#         else:
#             conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
#             if batch_norm:
#                 layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
#             else:
#                 layers += [conv2d, nn.ReLU(inplace=True)]
#             in_channels = v
#     return nn.Sequential(*layers)
#
#
# class VGGNet(VGG):
#     def __init__(self, pretrained=True, model='vgg16', requires_grad=True, remove_fc=True, show_params=False):
#         super().__init__(make_layers(cfg[model]))
#         self.ranges = ranges[model]
#
#         if pretrained:
#             exec("self.load_state_dict(models.%s(pretrained=True).state_dict())" % model)
#
#         if not requires_grad:
#             for param in super().parameters():
#                 param.requires_grad = False
#
#         if remove_fc:  # delete redundant fully-connected layer params, can save memory
#             del self.classifier
#
#         if show_params:
#             for name, param in self.named_parameters():
#                 print(name, param.size())
#
#     def forward(self, x):
#         output = {}
#
#         # get the output of each maxpooling layer (5 maxpool in VGG net)
#         for idx in range(len(self.ranges)):
#             for layer in range(self.ranges[idx][0], self.ranges[idx][1]):
#                 x = self.features[layer](x)
#             output["x%d"%(idx+1)] = x
#
#         return output
#
# class Intermediate(nn.Module):
#     def __init__(self):
#         super().__init__()
#         #x1 = 200      x2 = 150     x3 = 75     x4 = 50     x5 = 25
#         self.flatten = nn.Flatten(start_dim=1)
#         self.linear5 = nn.Linear(512*4*4,25)
#         self.linear4 = nn.Linear(512*8*8,50)
#         self.linear3 = nn.Linear(256*16*16,75)
#         self.linear2 = nn.Linear(128*32*32,150)
#         self.linear1 = nn.Linear(64*64*64,200)
#
#
#     def forward(self, x):
#         x5 = x['x5']  # size=(N, 512, x.H/32, x.W/32)
#         x4 = x['x4']  # size=(N, 512, x.H/16, x.W/16)
#         x3 = x['x3']  # size=(N, 256, x.H/8,  x.W/8)
#         x2 = x['x2']  # size=(N, 128, x.H/4,  x.W/4)
#         x1 = x['x1']  # size=(N, 64, x.H/2,  x.W/2)
#
#         flatten5 = self.flatten(x5)
#         linear5 = self.linear5(flatten5)
#         linear5 = linear5.permute(1,0)
#         flatten4 = self.flatten(x4)
#         linear4 = self.linear4(flatten4)
#         linear4 = linear4.permute(1,0)
#         flatten3 = self.flatten(x3)
#         linear3 = self.linear3(flatten3)
#         linear3 = linear3.permute(1,0)
#         flatten2 = self.flatten(x2)
#         linear2 = self.linear2(flatten2)
#         linear2 = linear2.permute(1,0)
#         flatten1 = self.flatten(x1)
#         linear1 = self.linear1(flatten1)
#         linear1 = linear1.permute(1,0)
#         LOGGER.info(linear5.shape)
#         LOGGER.info(linear4.shape)
#         res = t.cat((linear5,linear4,linear3,linear2,linear1),0)
#
#         res = res.permute(1,0)
#
#         return res
#
# class FCN_Bottom(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.vgg = VGGNet(requires_grad=True, remove_fc=True)
#         self.reduc = Intermediate()
#     def forward(self,x):
#         x = x[1]
#         x = self.vgg(x)
#         #LOGGER.info('x5:' + str(x['x5'].shape) + 'x4:' + str(x['x4'].shape) + 'x3:' + str(x['x3'].shape) + 'x2:' + str(x['x2'].shape) + 'x1:' + str(x['x1'].shape))
#         x = self.reduc(x)
#         #LOGGER.info('output')
#         #LOGGER.info(x.size())
#         return x

# %%
#bce = t.nn.BCEWithLogitsLoss()
bce = t.nn.BCELoss()

# %%
x = torch.ones([1, 2,2])
y = torch.ones([1, 2,2])

# %%
bce(x,y)
# Out:
# tensor(0.)

# %% [markdown]
# Then, we can use our models & loss in the Hetero-NN MNIST task! The usage is the same as Homo-NN: we specify our model and loss by nn.CustModel and nn.CustLoss interfaces.
#
# ## pipeline initialization
#
# Here we define the pipeline to run a hetero task

# %%
import os
import torch as t
from torch import nn
from pipeline import fate_torch_hook
from pipeline.component import HeteroNN
from pipeline.component.hetero_nn import DatasetParam
from pipeline.backend.pipeline import PipeLine
from pipeline.component import Reader, Evaluation, DataTransform
from pipeline.interface import Data, Model
from pipeline.component.nn import save_to_fate

fate_torch_hook(t)

# bind path to fate name&namespace
fate_project_path = os.path.abspath('/data/projects/fate')
guest = 10000
host = 9999

pipeline_img = PipeLine().set_initiator(role='guest', party_id=guest).set_roles(guest=guest, host=host)

guest_data = {"name": "fcn_guest", "namespace": "experiment"}
host_data = {"name": "fcn_host", "namespace": "experiment"}

guest_data_path = fate_project_path + '/examples/data/CamVid/train_labels/'
host_data_path = fate_project_path + '/examples/data/CamVid/train/'
pipeline_img.bind_table(name='fcn_guest', namespace='experiment', path=guest_data_path)
pipeline_img.bind_table(name='fcn_host', namespace='experiment', path=host_data_path)
# Out:
# {'namespace': 'experiment', 'table_name': 'fcn_host'}

# %%
guest_data = {"name": "fcn_guest", "namespace": "experiment"}
host_data = {"name": "fcn_host", "namespace": "experiment"}
reader_0 = Reader(name="reader_0")
reader_0.get_party_instance(role='guest', party_id=guest).component_param(table=guest_data)
reader_0.get_party_instance(role='host', party_id=host).component_param(table=host_data)

# %%
hetero_nn_0 = HeteroNN(name="hetero_nn_0", epochs=1,
                       interactive_layer_lr=0.01, batch_size=16, task_type='regression', seed=100
                       )
guest_nn_0 = hetero_nn_0.get_party_instance(role='guest', party_id=guest)
host_nn_0 = hetero_nn_0.get_party_instance(role='host', party_id=host)

# define model
# use cust model here
# our simple classification model:
guest_bottom = t.nn.CustModel(module_name='dummy.py', class_name='DummyNet')

# use cust model here
host_bottom = t.nn.CustModel(module_name='fcn_bottom.py', class_name='FCN_Bottom')

# use new top model here
guest_top = t.nn.CustModel(module_name='fcn_top.py', class_name='FCN_Top')

# interactive layer define
interactive_layer = t.nn.InteractiveLayer(out_dim=500, guest_dim=None, host_dim=500)

# add models
guest_nn_0.add_top_model(guest_top)
guest_nn_0.add_bottom_model(guest_bottom)
host_nn_0.add_bottom_model(host_bottom)

# opt, loss
optimizer = t.optim.SGD(guest_top.parameters(), lr=0.1, momentum=0.9)
loss = t.nn.BCEWithLogitsLoss()

# use DatasetParam to specify dataset and pass parameters
guest_nn_0.add_dataset(DatasetParam(dataset_name='vertseg', return_label=True))
host_nn_0.add_dataset(DatasetParam(dataset_name='vertimg', return_label=False))

hetero_nn_0.set_interactive_layer(interactive_layer)
hetero_nn_0.compile(optimizer=optimizer, loss=loss)

# %%
pipeline_img.add_component(reader_0)
pipeline_img.add_component(hetero_nn_0, data=Data(train_data=reader_0.output.data))
#pipeline_img.add_component(Evaluation(name='eval_0', eval_type='multi'), data=Data(data=hetero_nn_0.output.data))
pipeline_img.add_component(Evaluation(name='eval_0'), data=Data(data=hetero_nn_0.output.data))
pipeline_img.compile()

# %%
pipeline_img.fit()
# Out:
# 2023-09-27 23:52:39.420 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202309272352391699800
#
# 2023-09-27 23:52:39.427 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-09-27 23:52:40.446 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-09-27 23:52:40.447 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:01
# 2023-09-27 23:52:41.471 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-09-27 23:52:42.484 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-09-27 23:52:43.524 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-09-27 23:52:44.565 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# m2023-09-27 23:52:45.581 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-09-27 23:52:45.582 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:06
# 2023-09-27 23:52:46.595 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:07
# 2023-09-27 23:52:47.608 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:08
# 2023-09-27 23:52:48.620 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:09
# 2023-09-27 23:52:49.635 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:10
# 2023-09-27 23:52:50.647 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:11
# 2023-09-27 23:52:51.660 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:12
# 2023-09-27 23:52:52.687 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:13
# 2023-09-27 23:52:53.701 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:14
# 2023-09-27 23:52:54.713 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:15
# 2023-09-27 23:52:55.726 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:16
# 2023-09-27 23:52:56.738 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:17
# 2023-09-27 23:52:57.753 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:18
# 2023-09-27 23:52:58.767 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:19
# 2023-09-27 23:52:59.780 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:20
# 2023-09-27 23:53:00.793 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:21
# 2023-09-27 23:53:01.807 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:22
# 2023-09-27 23:53:02.819 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:23
# 2023-09-27 23:53:03.832 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:24
# 2023-09-27 23:53:04.846 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:25
# 2023-09-27 23:53:05.858 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:26
# 2023-09-27 23:53:06.871 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:27
# 2023-09-27 23:53:07.884 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:28
# 2023-09-27 23:53:08.896 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:29
# 2023-09-27 23:53:09.908 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:30
# 2023-09-27 23:53:10.921 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:31
# 2023-09-27 23:53:11.933 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:32
# 2023-09-27 23:53:12.945 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:33
# 2023-09-27 23:53:13.958 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:34
# 2023-09-27 23:53:14.970 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:35
# 2023-09-27 23:53:15.982 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:36
# 2023-09-27 23:53:16.995 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:37
# 2023-09-27 23:53:18.008 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:38
# 2023-09-27 23:53:19.020 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:39
# 2023-09-27 23:53:20.032 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:40
# 2023-09-27 23:53:21.045 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:41
# 2023-09-27 23:53:22.057 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:42
# 2023-09-27 23:53:23.071 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:43
# 2023-09-27 23:53:24.084 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:44
# 2023-09-27 23:53:25.098 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:45
# 2023-09-27 23:53:26.111 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:46
# 2023-09-27 23:53:27.124 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:47
# 2023-09-27 23:53:28.137 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:48
# 2023-09-27 23:53:29.149 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:49
# 2023-09-27 23:53:30.160 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:50
# 2023-09-27 23:53:31.173 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:51
# 2023-09-27 23:53:32.186 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:52
# 2023-09-27 23:53:33.199 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:53
# 2023-09-27 23:53:34.211 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:54
# 2023-09-27 23:53:35.223 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:55
# 2023-09-27 23:53:36.236 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:56
# 2023-09-27 23:53:37.248 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:57
# 2023-09-27 23:53:38.260 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:58
# 2023-09-27 23:53:39.274 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:00:59
# 2023-09-27 23:53:40.286 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:00
# 2023-09-27 23:53:41.297 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:01
# 2023-09-27 23:53:42.310 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:02
# 2023-09-27 23:53:43.322 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:03
# 2023-09-27 23:53:44.333 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:04
# 2023-09-27 23:53:45.346 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:05
# 2023-09-27 23:53:46.362 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:06
# 2023-09-27 23:53:47.373 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:07
# 2023-09-27 23:53:48.398 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:08
# 2023-09-27 23:53:49.411 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:09
# 2023-09-27 23:53:50.429 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:11
# 2023-09-27 23:53:51.440 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:12
# 2023-09-27 23:53:52.453 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:13
# 2023-09-27 23:53:53.467 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:14
# 2023-09-27 23:53:54.478 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:15
# 2023-09-27 23:53:55.490 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:16
# 2023-09-27 23:53:56.502 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:17
# 2023-09-27 23:53:57.515 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:18
# 2023-09-27 23:53:58.527 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:19
# 2023-09-27 23:53:59.539 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:20
# 2023-09-27 23:54:00.551 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:21
# 2023-09-27 23:54:01.563 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:22
# 2023-09-27 23:54:02.575 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:23
# 2023-09-27 23:54:03.587 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:24
# 2023-09-27 23:54:04.599 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:25
# 2023-09-27 23:54:05.610 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:26
# 2023-09-27 23:54:06.622 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:27
# 2023-09-27 23:54:07.634 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:28
# 2023-09-27 23:54:08.645 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:29
# 2023-09-27 23:54:09.657 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:30
# 2023-09-27 23:54:10.669 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:31
# 2023-09-27 23:54:11.681 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:32
# 2023-09-27 23:54:12.694 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:33
# 2023-09-27 23:54:13.705 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:34
# 2023-09-27 23:54:14.717 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:35
# 2023-09-27 23:54:15.730 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:36
# 2023-09-27 23:54:16.742 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:37
# 2023-09-27 23:54:17.754 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:38
# 2023-09-27 23:54:18.766 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:39
# 2023-09-27 23:54:19.778 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:40
# 2023-09-27 23:54:20.790 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:41
# 2023-09-27 23:54:21.802 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:42
# 2023-09-27 23:54:22.814 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:43
# 2023-09-27 23:54:23.826 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:44
# 2023-09-27 23:54:24.838 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:45
# 2023-09-27 23:54:25.850 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:46
# 2023-09-27 23:54:26.862 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:47
# 2023-09-27 23:54:27.875 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:48
# 2023-09-27 23:54:28.887 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:49
# 2023-09-27 23:54:29.899 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:50
# 2023-09-27 23:54:30.910 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:51
# 2023-09-27 23:54:31.921 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:52
# 2023-09-27 23:54:32.934 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:53
# 2023-09-27 23:54:33.946 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:54
# 2023-09-27 23:54:34.958 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:55
# 2023-09-27 23:54:35.971 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:56
# 2023-09-27 23:54:36.983 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:57
# 2023-09-27 23:54:37.995 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:58
# 2023-09-27 23:54:39.007 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:01:59
# 2023-09-27 23:54:40.019 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:00
# 2023-09-27 23:54:41.032 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:01
# 2023-09-27 23:54:42.044 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:02
# 2023-09-27 23:54:43.056 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:03
# 2023-09-27 23:54:44.070 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:04
# 2023-09-27 23:54:45.082 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:05
# 2023-09-27 23:54:46.094 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:06
# 2023-09-27 23:54:47.107 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:07
# 2023-09-27 23:54:48.118 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:08
# 2023-09-27 23:54:49.130 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:09
# 2023-09-27 23:54:50.161 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:10
# 2023-09-27 23:54:51.174 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:11
# 2023-09-27 23:54:52.192 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:12
# 2023-09-27 23:54:53.205 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:13
# 2023-09-27 23:54:54.217 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:14
# 2023-09-27 23:54:55.229 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:15
# 2023-09-27 23:54:56.243 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:16
# 2023-09-27 23:54:57.256 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:17
# 2023-09-27 23:54:58.272 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:18
# 2023-09-27 23:54:59.284 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:19
# 2023-09-27 23:55:00.298 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:20
# 2023-09-27 23:55:01.310 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:21
# 2023-09-27 23:55:02.322 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:22
# 2023-09-27 23:55:03.334 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:23
# 2023-09-27 23:55:04.346 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:24
# 2023-09-27 23:55:05.359 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:25
# 2023-09-27 23:55:06.371 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:26
# 2023-09-27 23:55:07.384 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:27
# 2023-09-27 23:55:08.396 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:28
# 2023-09-27 23:55:09.410 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:29
# 2023-09-27 23:55:10.422 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:31
# 2023-09-27 23:55:11.435 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:32
# 2023-09-27 23:55:12.447 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:33
# 2023-09-27 23:55:13.465 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:34
# 2023-09-27 23:55:14.477 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:35
# 2023-09-27 23:55:15.489 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:36
# 2023-09-27 23:55:16.502 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:37
# 2023-09-27 23:55:17.514 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:38
# 2023-09-27 23:55:18.526 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:39
# 2023-09-27 23:55:19.538 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:40
# 2023-09-27 23:55:20.550 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:41
# 2023-09-27 23:55:21.562 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:42
# 2023-09-27 23:55:22.578 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:43
# 2023-09-27 23:55:23.590 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:44
# 2023-09-27 23:55:24.603 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:45
# 2023-09-27 23:55:25.615 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:46
# 2023-09-27 23:55:26.634 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:47
# 2023-09-27 23:55:27.656 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:48
# 2023-09-27 23:55:28.672 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:49
# 2023-09-27 23:55:29.689 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:50
# 2023-09-27 23:55:30.706 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:51
# 2023-09-27 23:55:31.720 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:52
# 2023-09-27 23:55:32.732 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:53
# 2023-09-27 23:55:33.746 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:54
# 2023-09-27 23:55:34.758 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:55
# 2023-09-27 23:55:35.770 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:56
# 2023-09-27 23:55:36.788 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:57
# 2023-09-27 23:55:37.801 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:58
# 2023-09-27 23:55:38.814 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:02:59
# 2023-09-27 23:55:39.827 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:00
# 2023-09-27 23:55:40.839 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:01
# 2023-09-27 23:55:41.851 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:02
# 2023-09-27 23:55:42.864 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:03
# 2023-09-27 23:55:43.877 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:04
# 2023-09-27 23:55:44.889 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:05
# 2023-09-27 23:55:45.901 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:06
# 2023-09-27 23:55:46.914 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:07
# 2023-09-27 23:55:47.926 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:08
# 2023-09-27 23:55:48.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:09
# 2023-09-27 23:55:49.952 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:10
# 2023-09-27 23:55:50.964 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:11
# 2023-09-27 23:55:51.976 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:12
# 2023-09-27 23:55:52.988 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:13
# 2023-09-27 23:55:54.000 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:14
# 2023-09-27 23:55:55.012 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:15
# 2023-09-27 23:55:56.024 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:16
# 2023-09-27 23:55:57.036 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:17
# 2023-09-27 23:55:58.047 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:18
# 2023-09-27 23:55:59.066 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:19
# 2023-09-27 23:56:00.086 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:20
# 2023-09-27 23:56:01.106 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:21
# 2023-09-27 23:56:02.118 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:22
# 2023-09-27 23:56:03.143 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:23
# 2023-09-27 23:56:04.155 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:24
# 2023-09-27 23:56:05.171 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:25
# 2023-09-27 23:56:06.183 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:26
# 2023-09-27 23:56:07.196 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:27
# 2023-09-27 23:56:08.209 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:28
# 2023-09-27 23:56:09.221 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:29
# 2023-09-27 23:56:10.233 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:30
# 2023-09-27 23:56:11.245 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:31
# 2023-09-27 23:56:12.258 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:32
# 2023-09-27 23:56:13.270 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:33
# 2023-09-27 23:56:14.282 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:34
# 2023-09-27 23:56:15.294 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:35
# 2023-09-27 23:56:16.306 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:36
# 2023-09-27 23:56:17.318 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:37
# 2023-09-27 23:56:18.330 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:38
# 2023-09-27 23:56:19.343 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:39
# 2023-09-27 23:56:20.355 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:40
# 2023-09-27 23:56:21.367 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:41
# 2023-09-27 23:56:22.380 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:42
# 2023-09-27 23:56:23.392 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:43
# 2023-09-27 23:56:24.404 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:44
# 2023-09-27 23:56:25.415 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:45
# 2023-09-27 23:56:26.427 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:47
# 2023-09-27 23:56:27.439 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:48
# 2023-09-27 23:56:28.452 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:49
# 2023-09-27 23:56:29.463 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:50
# 2023-09-27 23:56:30.476 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:51
# 2023-09-27 23:56:31.488 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:52
# 2023-09-27 23:56:32.500 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:53
# 2023-09-27 23:56:33.513 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:54
# 2023-09-27 23:56:34.525 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:55
# 2023-09-27 23:56:35.537 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:56
# 2023-09-27 23:56:36.549 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:57
# 2023-09-27 23:56:37.561 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:58
# 2023-09-27 23:56:38.573 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:03:59
# 2023-09-27 23:56:39.585 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:00
# 2023-09-27 23:56:40.597 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:01
# 2023-09-27 23:56:41.609 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:02
# 2023-09-27 23:56:42.620 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:03
# 2023-09-27 23:56:43.632 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:04
# 2023-09-27 23:56:44.643 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:05
# 2023-09-27 23:56:45.655 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:06
# 2023-09-27 23:56:46.667 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:07
# 2023-09-27 23:56:47.680 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:08
# 2023-09-27 23:56:48.692 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:09
# 2023-09-27 23:56:49.704 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:10
# 2023-09-27 23:56:50.716 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:11
# 2023-09-27 23:56:51.727 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:12
# 2023-09-27 23:56:52.739 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:13
# 2023-09-27 23:56:53.750 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:14
# 2023-09-27 23:56:54.762 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:15
# 2023-09-27 23:56:55.774 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:16
# 2023-09-27 23:56:56.786 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:17
# 2023-09-27 23:56:57.798 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:18
# 2023-09-27 23:56:58.810 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:19
# 2023-09-27 23:56:59.822 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:20
# 2023-09-27 23:57:00.834 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:21
# 2023-09-27 23:57:01.846 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:22
# 2023-09-27 23:57:02.858 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:23
# 2023-09-27 23:57:03.872 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:24
# 2023-09-27 23:57:04.884 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:25
# 2023-09-27 23:57:05.896 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:26
# 2023-09-27 23:57:06.909 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:27
# 2023-09-27 23:57:07.921 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:28
# 2023-09-27 23:57:08.934 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:29
# 2023-09-27 23:57:09.946 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:30
# 2023-09-27 23:57:10.957 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:31
# 2023-09-27 23:57:11.969 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:32
# 2023-09-27 23:57:12.981 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:33
# 2023-09-27 23:57:13.993 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:34
# 2023-09-27 23:57:15.005 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:35
# 2023-09-27 23:57:16.017 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:36
# 2023-09-27 23:57:17.029 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:37
# 2023-09-27 23:57:18.041 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:38
# 2023-09-27 23:57:19.054 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:39
# 2023-09-27 23:57:20.068 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:40
# 2023-09-27 23:57:21.080 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:41
# 2023-09-27 23:57:22.092 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:42
# 2023-09-27 23:57:23.105 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:43
# 2023-09-27 23:57:24.118 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:44
# 2023-09-27 23:57:25.130 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:45
# 2023-09-27 23:57:26.143 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:46
# 2023-09-27 23:57:27.154 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:47
# 2023-09-27 23:57:28.166 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:48
# 2023-09-27 23:57:29.178 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:49
# 2023-09-27 23:57:30.191 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:50
# 2023-09-27 23:57:31.203 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:51
# 2023-09-27 23:57:32.216 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:52
# 2023-09-27 23:57:33.227 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:53
# 2023-09-27 23:57:34.242 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:54
# 2023-09-27 23:57:35.254 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:55
# 2023-09-27 23:57:36.267 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:56
# 2023-09-27 23:57:37.279 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:57
# 2023-09-27 23:57:38.291 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:58
# 2023-09-27 23:57:39.304 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:04:59
# 2023-09-27 23:57:40.316 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:00
# 2023-09-27 23:57:41.327 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:01
# 2023-09-27 23:57:42.339 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:02
# 2023-09-27 23:57:43.351 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:03
# 2023-09-27 23:57:44.364 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:04
# 2023-09-27 23:57:45.376 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:05
# 2023-09-27 23:57:46.387 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:06
# 2023-09-27 23:57:47.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:07
# 2023-09-27 23:57:48.412 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:08
# 2023-09-27 23:57:49.424 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:10
# 2023-09-27 23:57:50.436 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:11
# 2023-09-27 23:57:51.448 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:12
# 2023-09-27 23:57:52.460 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:13
# 2023-09-27 23:57:53.473 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:14
# 2023-09-27 23:57:54.484 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:15
# 2023-09-27 23:57:55.496 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:16
# 2023-09-27 23:57:56.509 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:17
# 2023-09-27 23:57:57.520 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 0:05:18
# ...
# 2023-09-28 01:05:23.367 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:43
# 2023-09-28 01:05:24.381 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:44
# 2023-09-28 01:05:25.394 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:45
# 2023-09-28 01:05:26.406 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:46
# 2023-09-28 01:05:27.418 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:47
# 2023-09-28 01:05:28.431 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:49
# 2023-09-28 01:05:29.443 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:50
# 2023-09-28 01:05:30.458 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:51
# 2023-09-28 01:05:31.518 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:52
# 2023-09-28 01:05:32.533 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:53
# 2023-09-28 01:05:33.545 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:54
# 2023-09-28 01:05:34.557 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:55
# 2023-09-28 01:05:35.570 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:56
# 2023-09-28 01:05:36.583 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:57
# 2023-09-28 01:05:37.597 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:58
# 2023-09-28 01:05:38.610 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:12:59
# 2023-09-28 01:05:39.623 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:00
# 2023-09-28 01:05:40.637 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:01
# 2023-09-28 01:05:41.650 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:02
# 2023-09-28 01:05:42.663 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:03
# 2023-09-28 01:05:43.677 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:04
# 2023-09-28 01:05:44.690 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:05
# 2023-09-28 01:05:45.707 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:06
# 2023-09-28 01:05:46.719 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:07
# 2023-09-28 01:05:47.737 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:08
# 2023-09-28 01:05:48.750 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:09
# 2023-09-28 01:05:49.761 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:10
# 2023-09-28 01:05:50.774 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:11
# 2023-09-28 01:05:51.787 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:12
# 2023-09-28 01:05:52.800 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:13
# 2023-09-28 01:05:53.813 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:14
# 2023-09-28 01:05:54.826 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:15
# 2023-09-28 01:05:55.840 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:16
# 2023-09-28 01:05:56.854 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:17
# 2023-09-28 01:05:57.867 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:18
# 2023-09-28 01:05:58.879 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:19
# 2023-09-28 01:05:59.892 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:20
# 2023-09-28 01:06:00.905 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:21
# 2023-09-28 01:06:01.917 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:22
# 2023-09-28 01:06:02.928 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:23
# 2023-09-28 01:06:03.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:24
# 2023-09-28 01:06:04.951 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:25
# 2023-09-28 01:06:05.963 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:26
# 2023-09-28 01:06:06.976 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:27
# 2023-09-28 01:06:07.990 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:28
# 2023-09-28 01:06:09.003 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:29
# 2023-09-28 01:06:10.016 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:30
# 2023-09-28 01:06:11.028 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:31
# 2023-09-28 01:06:12.040 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:32
# 2023-09-28 01:06:13.052 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:33
# 2023-09-28 01:06:14.065 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:34
# 2023-09-28 01:06:15.079 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:35
# 2023-09-28 01:06:16.091 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:36
# 2023-09-28 01:06:17.103 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:37
# 2023-09-28 01:06:18.116 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:38
# 2023-09-28 01:06:19.130 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:39
# 2023-09-28 01:06:20.142 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:40
# 2023-09-28 01:06:21.154 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:41
# 2023-09-28 01:06:22.166 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:42
# 2023-09-28 01:06:23.180 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:43
# 2023-09-28 01:06:24.191 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:44
# 2023-09-28 01:06:25.203 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:45
# 2023-09-28 01:06:26.215 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:46
# 2023-09-28 01:06:27.228 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:47
# 2023-09-28 01:06:28.240 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:48
# 2023-09-28 01:06:29.252 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:49
# 2023-09-28 01:06:30.265 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:50
# 2023-09-28 01:06:31.278 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:51
# 2023-09-28 01:06:32.290 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:52
# 2023-09-28 01:06:33.309 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:53
# 2023-09-28 01:06:34.322 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:54
# 2023-09-28 01:06:35.335 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:55
# 2023-09-28 01:06:36.347 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:56
# 2023-09-28 01:06:37.360 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:57
# 2023-09-28 01:06:38.373 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:58
# 2023-09-28 01:06:39.386 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:13:59
# 2023-09-28 01:06:40.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:00
# 2023-09-28 01:06:41.412 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:01
# 2023-09-28 01:06:42.426 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:03
# 2023-09-28 01:06:43.440 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:04
# 2023-09-28 01:06:44.454 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:05
# 2023-09-28 01:06:45.468 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:06
# 2023-09-28 01:06:46.481 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:07
# 2023-09-28 01:06:47.493 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:08
# 2023-09-28 01:06:48.506 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:09
# 2023-09-28 01:06:49.519 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:10
# 2023-09-28 01:06:50.532 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:11
# 2023-09-28 01:06:51.545 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:12
# 2023-09-28 01:06:52.557 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:13
# 2023-09-28 01:06:53.570 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:14
# 2023-09-28 01:06:54.582 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:15
# 2023-09-28 01:06:55.594 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:16
# 2023-09-28 01:06:56.606 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:17
# 2023-09-28 01:06:57.619 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:18
# 2023-09-28 01:06:58.632 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:19
# 2023-09-28 01:06:59.644 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:20
# 2023-09-28 01:07:00.657 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:21
# 2023-09-28 01:07:01.669 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:22
# 2023-09-28 01:07:02.681 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:23
# 2023-09-28 01:07:03.694 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:24
# 2023-09-28 01:07:04.707 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:25
# 2023-09-28 01:07:05.720 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:26
# 2023-09-28 01:07:06.732 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:27
# 2023-09-28 01:07:07.748 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:28
# 2023-09-28 01:07:08.761 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_nn_0, time elapse: 1:14:29

# %%
pipeline_img.get_component('hetero_nn_0').get_output_data()  # get result
# Out:
#              id                 label         predict_result  \
# 0         img_1    0.9450980424880981     0.4692811071872711
# 1         img_3    0.0235294122248888    0.13761655986309052
# 2         img_4  0.019607843831181526   0.002599237486720085
# 3         img_5                   0.0   0.026792803779244423
# 4         img_6    0.9607843160629272     0.2996892035007477
# ...         ...                   ...                    ...
# 1304  img_32537  0.003921568859368563    0.04695115610957146
# 1305  img_32558                   0.0    0.09780637919902802
# 1306  img_32563                   1.0     0.0337691493332386
# 1307  img_32565                   0.0     0.4692811071872711
# 1308  img_32573                   0.0  0.0011980474228039384
#
#               predict_score                    predict_detail   type
# 0        0.4692811071872711     {'label': 0.4692811071872711}  train
# 1       0.13761655986309052    {'label': 0.13761655986309052}  train
# 2      0.002599237486720085   {'label': 0.002599237486720085}  train
# 3      0.026792803779244423   {'label': 0.026792803779244423}  train
# 4        0.2996892035007477     {'label': 0.2996892035007477}  train
# ...                     ...                               ...    ...
# 1304    0.04695115610957146    {'label': 0.04695115610957146}  train
# 1305    0.09780637919902802    {'label': 0.09780637919902802}  train
# 1306     0.0337691493332386     {'label': 0.0337691493332386}  train
# 1307     0.4692811071872711     {'label': 0.4692811071872711}  train
# 1308  0.0011980474228039384  {'label': 0.0011980474228039384}  train
#
# [1309 rows x 6 columns]

# %%
print("Cole moment")
# Out:
# Cole moment
